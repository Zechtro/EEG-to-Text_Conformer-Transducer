# %%
import os
import pandas as pd
from IPython.display import display

# ============================================================================
# 1. PARAMETER SUBJEK, PERSENTIL, & METRIK
# ============================================================================
# Ubah nilai ini untuk mengganti subjek (contoh: 'SUB1', 'SUB2', dst.)
SUBJECT = 'SUB1'

# Ubah nilai ini untuk mengganti metrik target (contoh: 'cer', 'WER', 'BLEU-1', dll.)
TARGET_METRIC = 'cer'

# Titik persentil yang ingin ditampilkan
PERCENTILES = [0, 10, 25, 35, 50, 65, 75, 85, 95, 100]

# Mendapatkan direktori aktif notebook
script_dir = os.getcwd()

# ============================================================================
# 2. DAFTAR TEMPLATE NAMA FILE
# ============================================================================
file_templates = [
    # --- Versi Normal ---
    "complete_metrics_{subject}_eq_3_0_fixed_hilbert_test_predictions_6_1.csv",
    "complete_metrics_{subject}_eq_3_0_hilbert_test_predictions_10_1_IndoGPT.csv",
    "complete_metrics_{subject}_eq_3_0_log-mel_test_predictions_6_1.csv",
    "complete_metrics_{subject}_eq_3_0_logmel_test_predictions_10_1_IndoGPT.csv",
    
    # --- Versi Noise Baseline ---
    "complete_metrics_NOISE_BASELINE_{subject}_eq_3_0_fixed_hilbert_test_predictions_6_1.csv",
    "complete_metrics_NOISE_BASELINE_{subject}_eq_3_0_hilbert_test_predictions_10_1_IndoGPT.csv",
    "complete_metrics_NOISE_BASELINE_{subject}_eq_3_0_log-mel_test_predictions_6_1.csv",
    "complete_metrics_NOISE_BASELINE_{subject}_eq_3_0_logmel_test_predictions_10_1_IndoGPT.csv"
]

print(f"Menampilkan sampel prediksi pada persentil {TARGET_METRIC.upper()} untuk subjek: {SUBJECT}\n")

# ============================================================================
# 3. PROSES PEMBACAAN DAN PENAMPILAN TABEL
# ============================================================================
for template in file_templates:
    filename = template.format(subject=SUBJECT)
    filepath = os.path.join(script_dir, filename)
    
    print("=" * 110)
    print(f"📄 File: {filename}")
    print("=" * 110)
    
    if os.path.exists(filepath):
        try:
            df = pd.read_csv(filepath)
            
            # Pastikan kolom yang dibutuhkan ada sesuai metrik target
            req_cols = [TARGET_METRIC, 'sentence', 'prediction']
            if all(col in df.columns for col in req_cols):
                
                # 1. Urutkan dataframe berdasarkan metrik target dari terkecil ke terbesar
                df_sorted = df.sort_values(by=TARGET_METRIC).reset_index(drop=True)
                
                results = []
                n_rows = len(df_sorted)
                
                if n_rows > 0:
                    for p in PERCENTILES:
                        # 2. Cari index baris yang merepresentasikan persentil tersebut
                        # Rumus: (p / 100) * (total_baris - 1)
                        idx = int((p / 100.0) * (n_rows - 1))
                        row = df_sorted.iloc[idx]
                        
                        results.append({
                            'persentil': f"{p}",
                            TARGET_METRIC: round(row[TARGET_METRIC], 4),
                            'sentence': row['sentence'],
                            'prediction': row['prediction']
                        })
                    
                    # 3. Buat DataFrame dari hasil ekstraksi persentil dan tampilkan
                    df_result = pd.DataFrame(results)
                    display(df_result)
                else:
                    print("⚠️ File CSV kosong (tidak ada baris).")
            else:
                missing = [col for col in req_cols if col not in df.columns]
                print(f"⚠️ Peringatan: Kolom {missing} tidak ditemukan di dalam file ini.")
                
        except Exception as e:
            print(f"❌ Gagal membaca file: {e}")
    else:
        print(f"❌ File belum ditemukan di: {filepath}")
        
    print("\n")
# Out:
# Menampilkan sampel prediksi pada persentil CER untuk subjek: SUB1
#
# ==============================================================================================================
# 📄 File: complete_metrics_SUB1_eq_3_0_fixed_hilbert_test_predictions_6_1.csv
# ==============================================================================================================
#   persentil      cer                                  sentence  \
# 0         0  52.6316                       maaf saya terlambat
# 1        10  65.0000  silakan beri tahu saya nama lengkap anda
# 2        25  68.1818                    kita akan bertemu lagi
# 3        35  70.2703     apa yang bisa kami lakukan untuk anda
# 4        50  73.6842    anda benar benar kakek yang murah hati
# 5        65  75.7576         kamu tampak penuh energi hari ini
# 6        75  77.7778               saya bukan seorang penjahat
# 7        85  80.5556      kamu benar benar menjadi lebih sehat
# 8        95  82.7586             apakah anda sudah makan siang
# 9       100  82.7586             tolong segera pergi dari sini
#
#                            prediction
# 0                  sayur saya perinya
# 1               sayur tidak mengalian
# 2                    saya tukan separ
# 3                      silakan pintuk
# 4              selamat sedang pintaku
# 5                            hari ini
# 6                tolong bisa menalang
# 7                    silama saya anda
# 8  saya tidak sengaja anda bisa mebas
# 9                      pekerjaan anda
# ==============================================================================================================
# 📄 File: complete_metrics_SUB1_eq_3_0_hilbert_test_predictions_10_1_IndoGPT.csv
# ==============================================================================================================
#   persentil       cer                                  sentence  \
# 0         0   53.1250          benar benar tidak bisa dipercaya
# 1        10   62.9630               waktu berjalan begitu cepat
# 2        25   67.5000  silakan beri tahu saya nama lengkap anda
# 3        35   70.0000  saya tidak punya waktu luang sama sekali
# 4        50   72.2222      kamu benar benar menjadi lebih sehat
# 5        65   75.0000              dia bukan orang yang penting
# 6        75   81.0811     apa yang bisa kami lakukan untuk anda
# 7        85   84.0000                 bagaimana harimu hari ini
# 8        95   89.6552             tolong segera pergi dari sini
# 9       100  105.5556                        cobalah besok pagi
#
#                        prediction
# 0           saya tidak bisa makan
# 1         kami akan segera sampai
# 2      saya tidak bisa minta maaf
# 3  kamu adalah orang yang humoris
# 4  kamu adalah orang yang humoris
# 5           anda bisa mencetaknya
# 6  kamu adalah orang yang humoris
# 7     kami akan bertanggung jawab
# 8      saya tidak bisa minta maaf
# 9      saya tidak bisa minta maaf
# ==============================================================================================================
# 📄 File: complete_metrics_SUB1_eq_3_0_log-mel_test_predictions_6_1.csv
# ==============================================================================================================
#   persentil      cer                                  sentence  \
# 0         0  62.5000  setelah makan saya merasa sangat kenyang
# 1        10  68.1818                    kita akan bertemu lagi
# 2        25  70.3704               saya bukan seorang penjahat
# 3        35  74.0741               waktu berjalan begitu cepat
# 4        50  77.5000  silakan beri tahu saya nama lengkap anda
# 5        65  80.0000                 bagaimana harimu hari ini
# 6        75  81.0811     apa yang bisa kami lakukan untuk anda
# 7        85  82.7586             tolong segera pergi dari sini
# 8        95  87.5000          biar saya bantu ganti baterainya
# 9       100  88.8889                        cobalah besok pagi
#
#                      prediction
# 0      selamat benar saya bantu
# 1               saya saya bantu
# 2  silakan tidak bertanya malam
# 3                     maku anda
# 4                semora menunya
# 5            sembua sedang biar
# 6                  sialam siang
# 7     saya tidak berani menunya
# 8                      maaf ilu
# 9         silakan sedang menung
# ==============================================================================================================
# 📄 File: complete_metrics_SUB1_eq_3_0_logmel_test_predictions_10_1_IndoGPT.csv
# ==============================================================================================================
#   persentil       cer                                  sentence  \
# 0         0   59.2593               saya bukan seorang penjahat
# 1        10   59.4595     apa yang bisa kami lakukan untuk anda
# 2        25   65.6250          benar benar tidak bisa dipercaya
# 3        35   69.4444      kamu benar benar menjadi lebih sehat
# 4        50   71.8750          biar saya bantu ganti baterainya
# 5        65   74.1935           sebaiknya kita sarapan sekarang
# 6        75   77.5000  saya tidak punya waktu luang sama sekali
# 7        85   94.7368                       maaf saya terlambat
# 8        95  104.0000                 bagaimana harimu hari ini
# 9       100  111.1111                        cobalah besok pagi
#
#                               prediction
# 0             saya tidak akan minta maaf
# 1             saya tidak akan minta maaf
# 2             saya tidak akan minta maaf
# 3                kami akan segera sampai
# 4             saya tidak akan minta maaf
# 5             senang bertemu dengan anda
# 6     teroris tidak menghargai kehidupan
# 7             saya tidak akan minta maaf
# 8  selamat sore ada yang bisa saya bantu
# 9               kamu terlihat luar biasa
# ==============================================================================================================
# 📄 File: complete_metrics_NOISE_BASELINE_SUB1_eq_3_0_fixed_hilbert_test_predictions_6_1.csv
# ==============================================================================================================
#   persentil      cer                                sentence  \
# 0         0  59.3750        biar saya bantu ganti baterainya
# 1        10  63.1579                     maaf saya terlambat
# 2        25  72.2222    kamu benar benar menjadi lebih sehat
# 3        35  72.7273                  kita akan bertemu lagi
# 4        50  77.7778             waktu berjalan begitu cepat
# 5        65  81.0811   saya sedang terburu buru sampai jumpa
# 6        75  84.2105  anda benar benar kakek yang murah hati
# 7        85  85.7143            dia bukan orang yang penting
# 8        95  89.6552           apakah anda sudah makan siang
# 9       100  89.6552           tolong segera pergi dari sini
#
#                               prediction
# 0                      saya sangat siang
# 1                       saya akan pendat
# 2                 anda selamat sore anda
# 3                         saya kami untu
# 4                   saya risa sayurannya
# 5                          tidak seringa
# 6                               aku anda
# 7                              pekerjatu
# 8                                menuris
# 9  selamat sore anda yang bisa saya anda
# ==============================================================================================================
# 📄 File: complete_metrics_NOISE_BASELINE_SUB1_eq_3_0_hilbert_test_predictions_10_1_IndoGPT.csv
# ==============================================================================================================
#   persentil       cer                                  sentence  \
# 0         0   53.1250          benar benar tidak bisa dipercaya
# 1        10   54.5455                    kita akan bertemu lagi
# 2        25   65.5172             apakah anda sudah makan siang
# 3        35   67.5000  silakan beri tahu saya nama lengkap anda
# 4        50   68.4211    anda benar benar kakek yang murah hati
# 5        65   71.8750          biar saya bantu ganti baterainya
# 6        75   75.0000              dia bukan orang yang penting
# 7        85   81.0811     saya sedang terburu buru sampai jumpa
# 8        95   89.6552             tolong segera pergi dari sini
# 9       100  111.1111                        cobalah besok pagi
#
#                     prediction
# 0   saya tidak bisa minta maaf
# 1             kami akan segera
# 2   saya tidak bisa minta maaf
# 3   saya tidak bisa minta maaf
# 4   saya tidak bisa minta maaf
# 5   saya tidak bisa minta maaf
# 6             kami akan segera
# 7                    anda bisa
# 8   saya tidak bisa minta maaf
# 9  kami akan bertanggung jawab
# ==============================================================================================================
# 📄 File: complete_metrics_NOISE_BASELINE_SUB1_eq_3_0_log-mel_test_predictions_6_1.csv
# ==============================================================================================================
#   persentil      cer                                  sentence  \
# 0         0  60.0000  silakan beri tahu saya nama lengkap anda
# 1        10  68.1818                    kita akan bertemu lagi
# 2        25  73.6842                       maaf saya terlambat
# 3        35  75.0000  setelah makan saya merasa sangat kenyang
# 4        50  77.7778               waktu berjalan begitu cepat
# 5        65  80.0000                 bagaimana harimu hari ini
# 6        75  81.2500          biar saya bantu ganti baterainya
# 7        85  81.8182         kamu tampak penuh energi hari ini
# 8        95  92.5000  saya tidak punya waktu luang sama sekali
# 9       100  94.4444                        cobalah besok pagi
#
#                prediction
# 0  selamat sore nona anda
# 1        sekarang berinya
# 2      kami apan menelepo
# 3   ada berangi malam ada
# 4             kami apanya
# 5     anda berani menanya
# 6          menurutku anda
# 7               saya unda
# 8                   separ
# 9   maaf saya punda penal
# ==============================================================================================================
# 📄 File: complete_metrics_NOISE_BASELINE_SUB1_eq_3_0_logmel_test_predictions_10_1_IndoGPT.csv
# ==============================================================================================================
#   persentil       cer                                  sentence  \
# 0         0   64.5161           sebaiknya kita sarapan sekarang
# 1        10   65.0000  setelah makan saya merasa sangat kenyang
# 2        25   72.5000  saya tidak punya waktu luang sama sekali
# 3        35   73.6842    anda benar benar kakek yang murah hati
# 4        50   80.0000                 bagaimana harimu hari ini
# 5        65   86.2069             tolong segera pergi dari sini
# 6        75   88.8889               saya bukan seorang penjahat
# 7        85   93.1034             apakah anda sudah makan siang
# 8        95  131.5789                       maaf saya terlambat
# 9       100  161.1111                        cobalah besok pagi
#
#                               prediction
# 0             saya tidak akan minta maaf
# 1  selamat sore ada yang bisa saya bantu
# 2  selamat sore ada yang bisa saya bantu
# 3  selamat sore ada yang bisa saya bantu
# 4             saya tidak akan minta maaf
# 5  selamat sore ada yang bisa saya bantu
# 6     selamat sore ada yang bisa dibantu
# 7  selamat sore ada yang bisa saya bantu
# 8  selamat sore ada yang bisa saya bantu
# 9  selamat sore ada yang bisa saya bantu
